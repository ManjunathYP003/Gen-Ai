# %%
pip install unstructured
# Out:
# Requirement already satisfied: unstructured in c:\Users\manju\anaconda3\Lib\site-packages (0.27.5)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.14.3 in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from unstructured) (4.14.3)
# Requirement already satisfied: charset-normalizer<4.0.0,>=3.4.4 in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from unstructured) (3.4.4)
# Requirement already satisfied: emoji<3.0.0,>=2.15.0 in c:\Users\manju\anaconda3\Lib\site-packages (from unstructured) (2.15.0)
# Requirement already satisfied: filelock<4.0.0,>=3.12.0 in c:\Users\manju\anaconda3\Lib\site-packages (from unstructured) (3.20.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\Users\manju\anaconda3\Lib\site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: html5lib<2.0.0,>=1.1 in c:\Users\manju\anaconda3\Lib\site-packages (from unstructured) (1.1)
# Requirement already satisfied: installer<1.0.0,>=0.7.0 in c:\Users\manju\anaconda3\Lib\site-packages (from unstructured) (0.7.0)
# Requirement already satisfied: langdetect<2.0.0,>=1.0.9 in c:\Users\manju\anaconda3\Lib\site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: lxml<7.0.0,>=5.0.0 in c:\Users\manju\anaconda3\Lib\site-packages (from unstructured) (5.3.0)
# Requirement already satisfied: nh3<1.0.0,>=0.3.0 in c:\Users\manju\anaconda3\Lib\site-packages (from unstructured) (0.3.7)
# Requirement already satisfied: numba<1.0.0,>=0.60.0 in c:\Users\manju\anaconda3\Lib\site-packages (from unstructured) (0.62.1)
# Requirement already satisfied: numpy<3.0.0,>=1.26.0 in c:\Users\manju\anaconda3\Lib\site-packages (from unstructured) (2.3.5)
# Requirement already satisfied: psutil<8.0.0,>=7.2.2 in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from unstructured) (7.2.2)
# Requirement already satisfied: python-iso639<2027.0.0,>=2026.1.31 in c:\Users\manju\anaconda3\Lib\site-packages (from unstructured) (2026.7.23)
# Requirement already satisfied: python-magic<1.0.0,>=0.4.27 in c:\Users\manju\anaconda3\Lib\site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: python-oxmsg<1.0.0,>=0.0.2 in c:\Users\manju\anaconda3\Lib\site-packages (from unstructured) (0.0.2)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.14.3 in c:\Users\manju\anaconda3\Lib\site-packages (from unstructured) (3.14.6)
# Requirement already satisfied: regex<2027.0.0,>=2024.0.0 in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from unstructured) (2026.5.9)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\Users\manju\anaconda3\Lib\site-packages (from unstructured) (2.32.5)
# Requirement already satisfied: spacy<4.0.0,>=3.7.0 in c:\Users\manju\anaconda3\Lib\site-packages (from unstructured) (3.8.16)
# Requirement already satisfied: tqdm<5.0.0,>=4.67.3 in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from unstructured) (4.67.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.15.0 in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from unstructured) (4.15.0)
# Requirement already satisfied: unstructured-client<1.0.0,>=0.25.9 in c:\Users\manju\anaconda3\Lib\site-packages (from unstructured) (0.46.2)
# Requirement already satisfied: wrapt<3.0.0,>=2.1.1 in c:\Users\manju\anaconda3\Lib\site-packages (from unstructured) (2.4.0)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from beautifulsoup4<5.0.0,>=4.14.3->unstructured) (2.8.3)
# Requirement already satisfied: six>=1.9 in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from html5lib<2.0.0,>=1.1->unstructured) (1.17.0)
# Requirement already satisfied: webencodings in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from html5lib<2.0.0,>=1.1->unstructured) (0.5.1)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\Users\manju\anaconda3\Lib\site-packages (from numba<1.0.0,>=0.60.0->unstructured) (0.45.1)
# Requirement already satisfied: click in c:\Users\manju\anaconda3\Lib\site-packages (from python-oxmsg<1.0.0,>=0.0.2->unstructured) (8.5.0)
# Requirement already satisfied: olefile in c:\Users\manju\anaconda3\Lib\site-packages (from python-oxmsg<1.0.0,>=0.0.2->unstructured) (0.47)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from requests<3.0.0,>=2.32.5->unstructured) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from requests<3.0.0,>=2.32.5->unstructured) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\Users\manju\anaconda3\Lib\site-packages (from requests<3.0.0,>=2.32.5->unstructured) (2025.11.12)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\Users\manju\anaconda3\Lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\Users\manju\anaconda3\Lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\Users\manju\anaconda3\Lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\Users\manju\anaconda3\Lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\Users\manju\anaconda3\Lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in c:\Users\manju\anaconda3\Lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\Users\manju\anaconda3\Lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in c:\Users\manju\anaconda3\Lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\Users\manju\anaconda3\Lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in c:\Users\manju\anaconda3\Lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in c:\Users\manju\anaconda3\Lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\Users\manju\anaconda3\Lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (0.17.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.13.4)
# Requirement already satisfied: jinja2 in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (3.1.6)
# Requirement already satisfied: setuptools in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (80.10.2)
# Requirement already satisfied: packaging>=20.0 in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (26.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.7.0->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.7.0->unstructured) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.7.0->unstructured) (0.4.2)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\Users\manju\anaconda3\Lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy<4.0.0,>=3.7.0->unstructured) (1.3.3)
# Requirement already satisfied: colorama in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from tqdm<5.0.0,>=4.67.3->unstructured) (0.4.6)
# Requirement already satisfied: shellingham>=1.3.0 in c:\Users\manju\anaconda3\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\Users\manju\anaconda3\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (14.2.0)
# Requirement already satisfied: aiofiles>=25.1.0 in c:\Users\manju\anaconda3\Lib\site-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (25.1.0)
# Requirement already satisfied: httpcore>=1.0.9 in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (1.0.9)
# Requirement already satisfied: httpx>=0.28.1 in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (0.28.1)
# Requirement already satisfied: pypdf>=6.9.2 in c:\Users\manju\anaconda3\Lib\site-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (6.17.0)
# Requirement already satisfied: pypdfium2>=5.6.0 in c:\Users\manju\anaconda3\Lib\site-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (5.13.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Users\manju\anaconda3\Lib\site-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (1.0.0)
# Requirement already satisfied: cloudpathlib>=0.7.0 in c:\Users\manju\anaconda3\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.7.0->unstructured) (0.25.0)
# Requirement already satisfied: smart-open>=5.2.1 in c:\Users\manju\anaconda3\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.7.0->unstructured) (8.0.1)
# Requirement already satisfied: h11>=0.16 in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from httpcore>=1.0.9->unstructured-client<1.0.0,>=0.25.9->unstructured) (0.16.0)
# Requirement already satisfied: anyio in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from httpx>=0.28.1->unstructured-client<1.0.0,>=0.25.9->unstructured) (4.12.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Users\manju\anaconda3\Lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\Users\manju\anaconda3\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from jinja2->spacy<4.0.0,>=3.7.0->unstructured) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (4.14.3)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\manju\AppData\Roaming\Python\Python313\site-packages (from beautifulsoup4) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader

# %%
loader=CSVLoader(
    file_path="C:\\Users\\manju\\Downloads\\Student_Performance.csv"
)
docs=loader.load()
len(docs)
# Out:
# 10000

# %%
type(docs)
# Out:
# list

# %%
docs[0].metadata
# Out:
# {'source': 'C:\\Users\\manju\\Downloads\\Student_Performance.csv', 'row': 0}

# %%
print(docs[0].page_content)
# Out:
# Hours Studied: 7
# Previous Scores: 99
# Extracurricular Activities: Yes
# Sleep Hours: 9
# Sample Question Papers Practiced: 1
# Performance Index: 91.0

# %%
from langchain_community.document_loaders import UnstructuredURLLoader

# %%
# loader=UnstructuredURLLoader(
#     urls=[ "https://www.bbc.com/news"]
# )
# data=loader.load()

# %%
import os
os.environ["USER_AGENT"] = "Mozilla/5.0"

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader(
   "https://www.bbc.com/news"
)

data = loader.load()

print(data[0].page_content[:1000])
# Out:
# BBC News - Breaking news, video and the latest top stories from the U.S. and around the worldSkip to contentBritish Broadcasting CorporationHomeNewsSportBusinessTechnologyHealthCultureArtsTravelEarthAudioVideoLiveUS & CanadaUKAfricaAsiaAustraliaEuropeLatin AmericaMiddle EastIn PicturesBBC InDepthBBC VerifyHomeNewsUS & CanadaUKUK PoliticsEnglandN. IrelandN. Ireland PoliticsScotlandScotland PoliticsWalesWales PoliticsAfricaAsiaChinaIndiaAustraliaEuropeLatin AmericaMiddle EastIn PicturesBBC InDepthBBC VerifySportBusinessWorld of BusinessTechnology of BusinessNYSE Opening BellTechnologyArtificial IntelligenceIntelligence RevolutionAI v the MindTech NowHealthCultureFilm & TVMusicArt & DesignStyleBooksEntertainment NewsArtsArts in MotionTravelDestinationsAfricaAntarcticaAsiaAustralia and PacificCaribbean & BermudaCentral AmericaEuropeMiddle EastNorth AmericaSouth AmericaWorld’s TableCulture & ExperiencesAdventuresThe SpeciaListTo the Ends of the Earth EarthScienceNatural WondersClimate Solut
