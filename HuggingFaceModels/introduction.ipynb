# %%
pip install transformers
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
# !{sys.executable} -m pip install torch

# %%
from transformers import pipeline
cls=pipeline("sentiment-analysis")
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]

# %%
cls("I dont like this food")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.6867242455482483}]

# %%
cls("Pushpa movie was good but It did not reach the expectations")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.997692346572876}]

# %%
cls("hyderabadi biryani is very good highly satisfied")
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998348951339722}]
