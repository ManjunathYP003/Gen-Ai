# %%
import spacy

# %%
nlp=spacy.load('en_core_web_sm')
doc=nlp("I like machine learning. Machine learning is useful.playing.I like meghana biryani in Banglore")

# %%
for word in doc:
    print(word)
# Out:
# I
# like
# machine
# learning
# .
# Machine
# learning
# is
# useful.playing
# .
# I
# like
# meghana
# biryani
# in
# Banglore

# %%
doc[:-1]
# Out:
# I like machine learning. Machine learning is useful.playing.I like meghana biryani in

# %%
type(nlp)
# Out:
# spacy.lang.en.English

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
for token in doc:
    print(token.text,"-->",token.lemma_)
# Out:
# I --> I
# like --> like
# machine --> machine
# learning --> learning
# . --> .
# Machine --> machine
# learning --> learning
# is --> be
# useful.playing --> useful.playing
# . --> .
# I --> I
# like --> like
# meghana --> meghana
# biryani --> biryani
# in --> in
# Banglore --> Banglore

# %%
for token in doc:
    print(token.text,"-->",token.is_stop)
# Out:
# I --> True
# like --> False
# machine --> False
# learning --> False
# . --> False
# Machine --> False
# learning --> False
# is --> True
# useful.playing --> False
# . --> False
# I --> True
# like --> False
# meghana --> False
# biryani --> False
# in --> True
# Banglore --> False

# %%
for token in doc:
    print(token.text,"-->",token.pos_)
# Out:
# I --> PRON
# like --> VERB
# machine --> NOUN
# learning --> NOUN
# . --> PUNCT
# Machine --> NOUN
# learning --> NOUN
# is --> AUX
# useful.playing --> ADJ
# . --> PUNCT
# I --> PRON
# like --> VERB
# meghana --> PROPN
# biryani --> PROPN
# in --> ADP
# Banglore --> PROPN

# %%
for token in doc:
    print(token.text,"-->",token.head)
# Out:
# I --> like
# like --> like
# machine --> learning
# learning --> like
# . --> like
# Machine --> learning
# learning --> is
# is --> is
# useful.playing --> is
# . --> is
# I --> like
# like --> like
# meghana --> biryani
# biryani --> like
# in --> biryani
# Banglore --> in

# %%
for token in doc:
    print(token.text,"-->",token.ent_iob_)
# Out:
# I --> O
# like --> O
# machine --> O
# learning --> O
# . --> O
# Machine --> O
# learning --> O
# is --> O
# useful.playing --> O
# . --> O
# I --> O
# like --> O
# meghana --> B
# biryani --> I
# in --> O
# Banglore --> B

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
for token in doc:
    print(token.text,"-->",token.ent_type_)
# Out:
# I -->
# like -->
# machine -->
# learning -->
# . -->
# Machine -->
# learning -->
# is -->
# useful.playing -->
# . -->
# I -->
# like -->
# meghana --> PERSON
# biryani --> PERSON
# in -->
# Banglore --> GPE

# %%
for token in doc.ents:
    print(token.text,"-->",token.label_)
# Out:
# meghana biryani --> PERSON
# Banglore --> GPE

# %%
for token in doc.ents:
    print(token.text,"-->",spacy.explain(token.label_))
# Out:
# meghana biryani --> People, including fictional
# Banglore --> Countries, cities, states
